# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print('Глава 3. Визуализация данных')
print(' Диограммы')
#Ориентированный на структуру график попытка 29
x_data = np.linspace(0, 20, 100)
y_data = np.sin(x_data)
f = plt.figure(figsize=(10,5))
a = plt.axes()
plt.plot(x_data, y_data, color='b', linewidth='2.0')
plt.grid('g--',linewidth='0.8')
plt.xlabel('Ось х')
plt.ylabel('Ось y')
plt.title('Ориентированный на структуру')
plt.show()
# Out:
# Глава 3. Визуализация данных

# %%
#Ориентированный на объект график попытка 17
x_data = np.linspace(0, 20, 100) #Функция numpy.linspace() в Python используется для генерации последовательности чисел в линейном пространстве с одинаковым размером шага.
y_data = np.sin(x_data)
plt.plot(x_data, y_data, color='b', linewidth='2.0')
plt.grid('g--',linewidth='0.8') #Метод grid() в объекте размеров используется для настройки доступности сетки в графике. Его можно было включить или выключить. Метод grid() позволяет пользователю изменять стиль линии и атрибуты пропускной способности.
plt.xlabel('Ось х')
plt.ylabel('Ось y')
plt.title('Ориентированный на объект')
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
ax = plt.axes()
plt.plot(x_data, y_data, linewidth='1.0', marker='o')
plt.grid('g--',linewidth='0.8')
plt.xlabel('Ось х')
plt.ylabel('Ось y')
plt.show()

# %%
import random
x_data = [random.randint(0,100) for x in range(100)]

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3, figsize=(15,10))

ax1.hist(x_data, bins = 10, color = 'b')
ax2.hist(x_data, bins = 30, color = 'g')
ax3.hist(x_data, bins = 50, color = 'r')

ax4.hist(x_data, bins = 20, color = 'b')
ax5.hist(x_data, bins = 40, color = 'g')
ax6.hist(x_data, bins = 40, color = 'r')

plt.show()

# %%
import pandas as pd
heights = [188, 172, 187, 161, 183, 172, 185, 163, 173,
           183, 174, 174, 175, 178, 183, 195, 178, 173,
           174, 183, 174, 181, 162, 180, 170, 175, 182,
           180, 183, 178, 182, 188, 175, 179, 184, 193,
           182, 183, 175, 185, 182, 183, 156, 185, 199]

gender = ['male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'female',
           'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female',
           'female', 'male', 'female', 'male', 'female', 'male', 'female', 'female', 'female',
           'female', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male',
           'male', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'male']

weights = [86, 71, 89, 64, 83, 71, 86, 68, 73, 84, 73,
           72, 75, 78, 85, 93, 78, 70, 74, 80, 83, 82,
           68, 80, 73, 78, 82, 81, 83, 79, 82, 86, 76,
           77, 80, 103, 82, 83, 77, 89, 80, 85, 82, 85, 110]

ages = [58, 61, 54, 54, 58, 57, 63, 54, 37, 51, 34,
        26, 50, 48, 45, 52, 56, 46, 54, 28, 52, 47,
        55, 55, 54, 42, 51, 56, 55, 51, 54, 32, 21,
        62, 43, 55, 56, 61, 53, 22, 64, 45, 54, 47, 38]

data_dict = {'heights':(heights), 'weights': (weights), 'ages': (ages), 'gender': (gender)}
df = pd.DataFrame(data_dict)
plt.scatter( df['heights'],df['weights'],color='g', marker='o')
plt.xlabel('heights')
plt.ylabel('weights')
plt.title('График heights/weight')
plt.show()
df.plot(kind= 'scatter', x = 'heights', y = 'ages',color='b', title= 
'График heights/ages')
plt.show()
df.plot(kind= 'scatter', x = 'weights', y = 'ages',color='y', title= 
'График weights/ages')
plt.show()

# %%
print(' Гистограммы')
# Out:
#  Гистограммы

# %%
df['heights'].plot(
    kind = 'hist',
    title = 'heights',
    bins = 5)

plt.show()


df['weights'].plot(
    kind = 'hist',
    title = 'weights',
    bins = 5,
    color = 'r')

plt.show()

df['ages'].plot(
    kind = 'hist',
    title = 'ages',
    bins = 5,
    color = 'g')

plt.show()

gender_cnt = df['gender'].value_counts()

plt.style.use('ggplot')
gender_cnt.plot(kind = 'bar')
plt.show()

# %%
print('1.5')
df_describe = df.describe()

print(df_describe, end='\n'*3)
print('Межквартильное расстояние:\n', df_describe.loc['75%']-df_describe.loc['25%']) # обрати внимание, можно выводить таким образом значения
# Out:
# 1.5
#           heights     weights       ages
# count   45.000000   45.000000  45.000000
# mean   178.888889   80.422222  49.133333
# std      8.501931    8.438249  10.674098
# min    156.000000   64.000000  21.000000
# 25%    174.000000   75.000000  45.000000
# 50%    180.000000   80.000000  53.000000
# 75%    183.000000   84.000000  55.000000
# max    199.000000  110.000000  64.000000
#
#
# Межквартильное расстояние:
#  heights     9.0
# weights     9.0
# ages       10.0
# dtype: float64

# %%
import numpy as np

plt.style.use ('classic')

plt.boxplot(heights)
plt.title('heights')
plt.show()

plt.boxplot(weights)
plt.title('weights')
plt.show()

plt.boxplot(ages)
plt.title('ages')
plt.show()
